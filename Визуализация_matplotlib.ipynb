# %% [markdown]
# <a href="https://colab.research.google.com/github/inw1ze/SQL-study-project/blob/main/%D0%92%D0%B8%D0%B7%D1%83%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D1%8F_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cod.dtypes
# Out:
# id              int64
# created_at     object
# problem_id      int64
# user_id         int64
# language_id     int64
# dtype: object

# %%
user =  pd.read_csv('/content/itresume-users.csv', encoding = '1251', sep= ',')
cod = pd.read_csv('/content/itresume-coderun.csv', encoding = '1251')

# %%
cod['dt'] = pd.to_datetime(cod['created_at']).dt.strftime('%Y-%m')

# %%
a['id'].quantile(0.5)
# Out:
# np.float64(2555.0)

# %%
a = cod.groupby(['dt'])['id'].count().reset_index()

# %%
cod['dt'] = pd.to_datetime(cod['created_at']).dt.strftime('%Y-%m')

# %%
mean_val = a['id'].mean()
big_mean = a[a['id'] > mean_val]
min_mean = a[a['id'] < mean_val]
plt.plot(a['dt'],a['id'], alpha = 1)
plt.scatter(min_mean['dt'],min_mean['id'], color ='red')
plt.scatter(big_mean['dt'],big_mean['id'], color ='green')
plt.bar(a['dt'],a['id'], alpha = 0.5)
plt.xlabel('Период')
plt.ylabel('Количество попыток')
plt.title('Динамика попыток')
tic = plt.gca().get_xticks()
new_ticks = [x for x in tic if x%2==0]
label = plt.gca().get_xticklabels()
new_labels = [x for i, x in enumerate(label) if i%2==0]
plt.xticks(ticks = new_ticks, labels = new_labels, rotation = 90)
plt.grid(alpha=0.2)
plt.axhline(y=mean_val, alpha = 0.5, color ='red', linestyle = '--')

# %%
for_lin_and_pie = cod.groupby(['dt'])['id'].agg(['count']).reset_index()

# %%
for_lin_and_pie
# Out:
#         dt  count
# 0  2021-03      7
# 1  2021-04     23
# 2  2021-06    208
# 3  2021-07     56
# 4  2021-09    247
# 5  2021-10    239
# 6  2021-11   2555
# 7  2021-12   3998
# 8  2022-01  11788
# 9  2022-02   6938

# %%
plt.scatter(sct['count'], sct['nunique'])
plt.xlabel('Количество попыток')
plt.ylabel('Количество уникальных пользователей')
plt.title('Корреляция пользователей и их попыток')
plt.grid(alpha=0.2)

# %%
a_sort = a.sort_values('id', ascending = True)
plt.barh(a_sort['dt'],a_sort['id'])
# Out:
# <BarContainer object of 13 artists>

# %%
for_hist = cod.groupby(['user_id', 'problem_id'])['id'].count().reset_index()
for_hist.columns = ['user_id', 'problem_id', 'cnt']

# %%
for_hist = for_hist[for_hist['cnt'] < 100]

# %%
plt.hist(for_hist['cnt'])
# Out:
# (array([5158.,  886.,  330.,  148.,   90.,   36.,   23.,   18.,    9.,
#            9.]),
#  array([ 1. , 10.7, 20.4, 30.1, 39.8, 49.5, 59.2, 68.9, 78.6, 88.3, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(for_hist['cnt'], bins=20)
# Out:
# (array([5.801e+03, 6.000e+02, 1.950e+02, 5.500e+01, 3.700e+01, 1.400e+01,
#         9.000e+00, 5.000e+00, 2.000e+00, 1.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00]),
#  array([  1. ,  16.2,  31.4,  46.6,  61.8,  77. ,  92.2, 107.4, 122.6,
#         137.8, 153. , 168.2, 183.4, 198.6, 213.8, 229. , 244.2, 259.4,
#         274.6, 289.8, 305. ]),
#  <BarContainer object of 20 artists>)

# %%
mean_val = for_lin_and_pie['count'].mean()
big_mean = for_lin_and_pie[for_lin_and_pie['count'] > mean_val]
min_mean = for_lin_and_pie[for_lin_and_pie['count'] < mean_val]
plt.plot(for_lin_and_pie['dt'],for_lin_and_pie['count'], alpha = 1)
plt.scatter(min_mean['dt'],min_mean['count'], color ='red')
plt.scatter(big_mean['dt'],big_mean['count'], color ='green')
plt.bar(for_lin_and_pie['dt'],for_lin_and_pie['count'], alpha = 0.5)
plt.xlabel('Период')
plt.ylabel('Количество попыток')
plt.title('Динамика попыток')
tic = plt.gca().get_xticks()
new_ticks = [x for x in tic if x%2==0]
label = plt.gca().get_xticklabels()
new_labels = [x for i, x in enumerate(label) if i%2==0]
plt.xticks(ticks = new_ticks, labels = new_labels, rotation = 90)
plt.grid(alpha=0.2)
plt.axhline(y=mean_val, alpha = 0.5, color ='red', linestyle = '--')

# %%
a['id'].quantile(0.5)
# Out:
# np.float64(2555.0)

# %%
plt.boxplot(a['id'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7aa4859858e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7aa4837cbe00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7aa482d17dd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7aa4837cae70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7aa4837cacc0>],
#  'means': []}

# %%
for_pie = cod.groupby(['language_id'])['problem_id'].count().reset_index()

# %%
plt.pie(for_pie['problem_id'], labels = for_pie['language_id'],explode = [0, 0.15])
# Out:
# ([<matplotlib.patches.Wedge at 0x7aa481bd9070>,
# ...
#  [Text(-0.8864577001725248, 0.6513008105359908, '2'),
#   Text(1.0073381838963957, -0.7401147095311046, '3')])

# %%
fig, ax = plt.subplots(2, 3)

# %%
ax[0, 0].plot([1,2,3,4,5], color = 'red')
ax[0, 1].plot([1,2,3,4,5], color = 'black')
ax[0, 2].plot([1,2,3,4,5], color = 'yellow')
ax[1, 0].plot([1,2,3,4,5], color = 'green')
ax[1, 1].plot([1,2,3,4,5], color = 'brown')
ax[1, 2].plot([1,2,3,4,5], color = 'red')
fig.tight_layout(pad = 3)

# %%
fig

# %%
fig, ax = plt.subplots(2, 2)

# %%
#fig.tight_layout(pad = 2)
amean_val = a['id'].mean()
big_mean = a[a['id'] > mean_val]
min_mean = a[a['id'] < mean_val]
ax[0, 0].plot(a['dt'],a['id'], alpha = 1)
ax[0, 0].scatter(min_mean['dt'],min_mean['id'], color ='red')
ax[0, 0].scatter(big_mean['dt'],big_mean['id'], color ='green')
ax[0, 0].bar(a['dt'],a['id'], alpha = 0.5)
ax[0, 0].set_xlabel('Период')
ax[0, 0].set_ylabel('Количество попыток')
#ax[0, 0].set_title('Динамика попыток')
tic = ax[0, 0].get_xticks()
new_ticks = [x for x in tic if x%2==0]
label = ax[0, 0].get_xticklabels()
new_labels = [x for i, x in enumerate(label) if i%2==0]
ax[0, 0].set_xticks(ticks = new_ticks, labels = new_labels, rotation = 90)
ax[0, 0].grid(alpha=0.2)
ax[0, 0].axhline(y=mean_val, alpha = 0.5, color ='red', linestyle = '--')
#fig.tight_layout(pad = 3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2329/2120377737.py in <cell line: 0>()
#      14 label = ax[0, 0].get_xticklabels()
#      15 new_labels = [x for i, x in enumerate(label) if i%2==0]
# ---> 16 ax[0, 0].set_xticks(ticks = new_ticks, labels = new_labels, rotation = 90)
#      17 ax[0, 0].grid(alpha=0.2)
#      18 ax[0, 0].axhline(y=mean_val, alpha = 0.5, color ='red', linestyle = '--')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      72
#      73         def wrapper(self, *args, **kwargs):
# ---> 74             return get_method(self)(*args, **kwargs)
#      75
#      76         wrapper.__module__ = owner.__module__
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in set_ticks(self, ticks, labels, minor, **kwargs)
# ...

# %%
ax[1, 1].pie(for_pie['problem_id'], labels = for_pie['language_id'],explode = [0, 0.15])
# Out:
# ([<matplotlib.patches.Wedge at 0x7aa481bd9880>,
# ...
#  [Text(-0.8864577001725248, 0.6513008105359908, '2'),
#   Text(1.0073381838963957, -0.7401147095311046, '3')])

# %%
a.sort_values('id')
# Out:
#          dt     id
# 0   2021-03      7
# 1   2021-04     23
# 3   2021-07     56
# 2   2021-06    208
# 5   2021-10    239
# 4   2021-09    247
# 6   2021-11   2555
# 12  2022-05   3682
# 7   2021-12   3998
# 10  2022-03   8425
# 11  2022-04  11545
# 8   2022-01  11788
# 9   2022-02  12949

# %%
a = a.sort_values('id')
ax[0, 1].barh(a_sort['dt'],a_sort['id'])
# Out:
# <BarContainer object of 13 artists>

# %%
ax[1,0].axis('off')
# Out:
# (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0))

# %%
fig.tight_layout(pad = 3)

# %%
fig

# %%
cod['dt1'] = pd.to_datetime(cod['created_at']).dt.date

# %%
for_together_grafic = cod.groupby(['dt1'])['user_id'].agg(['count', 'nunique']).reset_index()

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(for_together_grafic['dt1'], for_together_grafic['count'], label = 'Количество попыток')
ax2.plot(for_together_grafic['dt1'], for_together_grafic['nunique'], color = 'red', label = 'Количество пользователей')
h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1+h2, l1+l2)
